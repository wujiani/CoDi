# %%
import pandas as pd
import numpy as np
import pm4py
import os
from sklearn.neighbors import KernelDensity
import random
from collections import Counter
import copy
import warnings
warnings.filterwarnings("ignore")

# %%
# info of train_data
if_csv = False #
import_file = 'bac_cut.xes' #
id_column = 'REQUEST_ID'
act_column = 'concept:name'
time_column = 'time:timestamp'
resource_column = 'user'
state_column = 'lifecycle:transition'

dirStr, ext = os.path.splitext(import_file)
file_name = dirStr.split("\\")[-1]


data = pm4py.read.read_xes(import_file)

df = copy.deepcopy(pd.DataFrame(data,columns=[id_column, act_column, time_column, resource_column, state_column]))
# Out:
# parsing log, completed traces ::   0%|          | 0/200 [00:00<?, ?it/s]

# %%
df['waiting_time'] = None
df['process_time'] = None
df['last_complete_event'] = None
df['preceding_evts'] = None
df['paired_event'] = None
df['next'] = None
df['index'] = df.index
for key, group in df.groupby(id_column):
    flag = 0
    i = list(group.index)[0]
    preceding_evt = []
    not_complete_evt_idx = []
    j = 0
    df['waiting_time'].loc[i] = 0
    not_complete_evt_idx.append(i)
    i+=1
    while j<len(group)-1:
        j+=1
        cur_act = df.loc[i]
        if cur_act[state_column] == 'complete':
            flag = 0
            preceding_evt.append(cur_act.name)
            last_complete_evt_idx = i
            
            for each_idx in not_complete_evt_idx:
                to_pair = df.loc[each_idx]
                if (cur_act[act_column] == to_pair[act_column]) \
                and (cur_act[resource_column] == to_pair[resource_column]):
                    df['paired_event'].loc[i] = each_idx
                    not_complete_evt_idx.remove(each_idx)
                    df['process_time'].loc[i] = (df[time_column].loc[i] - df[time_column].loc[each_idx]).total_seconds()
                    df['last_complete_event'].loc[i] = df['last_complete_event'].loc[each_idx]
                    break
            
        else:
            if flag == 1:
                df['preceding_evts'].loc[i] = df['preceding_evts'].loc[i-1]
            else:
                df['preceding_evts'].loc[i] = preceding_evt#tuple(sorted, reverse=False))
            for each in df['preceding_evts'].loc[i]:
                if df['next'].loc[each] == None:
                    df['next'].loc[each] = [i]
                else:
                    temp = df['next'].loc[each]
                    temp.append(i)
                    df['next'].loc[each] = temp
            flag = 1
            preceding_evt = []
            not_complete_evt_idx.append(i)
            
            df['last_complete_event'].loc[i] = last_complete_evt_idx
            df['waiting_time'].loc[i] = (df[time_column].loc[i] - df[time_column].loc[last_complete_evt_idx]).total_seconds()
        i+=1

# %%
def fillna_parallel_data(bb):
    i = bb.index[0]
    j = 0 
    while j < len(bb):
        if bb[state_column].loc[i] == 'complete':
            paired = int(bb['paired_event'].loc[i])
            bb['process_time'].loc[paired] = bb['process_time'].loc[i] 
            bb['paired_event'].loc[paired] = i
            bb['next'].loc[paired] = bb['next'].loc[i]
            bb['waiting_time'].loc[i] = bb['waiting_time'].loc[paired] 
            bb['preceding_evts'].loc[i] = bb['preceding_evts'].loc[paired]
            bb['next'].loc[paired] = bb['next'].loc[i] 
        i+=1
        j+=1
fillna_parallel_data(df)

# %%
df
# Out:
#         REQUEST_ID                                       concept:name  \
# 0      20181011389                                    Request created
# 1      20181011389                                    Request created
# 2      20181011389          Evaluating Request (NO registered letter)
# 3      20181011389          Evaluating Request (NO registered letter)
# 4      20181011389  Service closure Request with network responsib...
# ...            ...                                                ...
# 2699  201812009435            Pending Request for Reservation Closure
# 2700  201812009435                        Pending Liquidation Request
# 2701  201812009435                        Pending Liquidation Request
# 2702  201812009435             Request completed with account closure
# 2703  201812009435             Request completed with account closure
#
#                 time:timestamp   user lifecycle:transition waiting_time  \
# 0    2018-04-13 10:32:10+00:00  00456                start            0
# 1    2018-04-13 10:33:08+00:00  00456             complete            0
# 2    2018-04-13 10:33:08+00:00  00456                start            0
# 3    2018-04-13 10:34:03+00:00  00456             complete            0
# 4    2018-04-13 11:20:52+00:00  00456                start         2809
# ...                        ...    ...                  ...          ...
# 2699 2019-01-10 12:39:26+00:00    BOC             complete            0
# 2700 2019-01-10 12:39:26+00:00    BOC                start            0
# 2701 2019-01-12 03:13:51+00:00    BOC             complete            0
# 2702 2019-01-12 03:13:51+00:00    BOC                start            0
# 2703 2019-01-12 03:13:51+00:00    BOC             complete            0
#
#      process_time last_complete_event preceding_evts paired_event    next  \
# 0              58                None           None            1     [2]
# 1              58                None           None            0     [2]
# 2              55                   1            [1]            3     [4]
# 3              55                   1            [1]            2     [4]
# 4             134                   3            [3]            5     [6]
# ...           ...                 ...            ...          ...     ...
# 2699          117                2697         [2697]         2698  [2700]
# 2700       138865                2699         [2699]         2701  [2702]
# 2701       138865                2699         [2699]         2700  [2702]
# 2702            0                2701         [2701]         2703    None
# 2703            0                2701         [2701]         2702    None
#
#       index
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
# ...     ...
# 2699   2699
# 2700   2700
# 2701   2701
# 2702   2702
# 2703   2703
#
# [2704 rows x 12 columns]

# %%
df = df[df[state_column]=='start']
df = df.rename(columns = {'concept:name':'activity'})
file = df[['REQUEST_ID','activity', 'user', 'waiting_time', 'process_time']]
file = file.reset_index()

# %%
file['activity'] = file['activity'].map(lambda x: '_'.join(x.split()))
file['user'] = file['user'].map(lambda x: '_'.join(x.split()))
file
# Out:
#       index    REQUEST_ID                                           activity  \
# 0         0   20181011389                                    Request_created
# 1         2   20181011389          Evaluating_Request_(NO_registered_letter)
# 2         4   20181011389  Service_closure_Request_with_network_responsib...
# 3         6   20181011389     Service_closure_Request_with_BO_responsibility
# 4         8   20181011389                       Network_Adjustment_Requested
# ...     ...           ...                                                ...
# 1347   2694  201812009435  Service_closure_Request_with_network_responsib...
# 1348   2696  201812009435     Service_closure_Request_with_BO_responsibility
# 1349   2698  201812009435            Pending_Request_for_Reservation_Closure
# 1350   2700  201812009435                        Pending_Liquidation_Request
# 1351   2702  201812009435             Request_completed_with_account_closure
#
#        user waiting_time process_time
# 0     00456            0           58
# 1     00456            0           55
# 2     00456         2809          134
# 3       BOC            0       957164
# 4     00456            0  1.88345e+07
# ...     ...          ...          ...
# 1347  00241       260338           67
# 1348    BOC            0       616007
# 1349    BOC            0          117
# 1350    BOC            0       138865
# 1351    BOC            0            0
#
# [1352 rows x 6 columns]

# %%
np.mean(file[file['activity'] == 'Request_completed_with_account_closure']['process_time'])
# Out:
# 0.0

# %%
import math
file['waiting_time'] = file['waiting_time'].map(lambda x: math.log(x+1))
file['process_time'] = file['process_time'].map(lambda x: math.log(x+1))
file
# Out:
#       index    REQUEST_ID                                           activity  \
# 0         0   20181011389                                    Request_created
# 1         2   20181011389          Evaluating_Request_(NO_registered_letter)
# 2         4   20181011389  Service_closure_Request_with_network_responsib...
# 3         6   20181011389     Service_closure_Request_with_BO_responsibility
# 4         8   20181011389                       Network_Adjustment_Requested
# ...     ...           ...                                                ...
# 1347   2694  201812009435  Service_closure_Request_with_network_responsib...
# 1348   2696  201812009435     Service_closure_Request_with_BO_responsibility
# 1349   2698  201812009435            Pending_Request_for_Reservation_Closure
# 1350   2700  201812009435                        Pending_Liquidation_Request
# 1351   2702  201812009435             Request_completed_with_account_closure
#
#        user  waiting_time  process_time
# 0     00456       0.00000      4.077537
# 1     00456       0.00000      4.025352
# 2     00456       7.94094      4.905275
# 3       BOC       0.00000     13.771731
# 4     00456       0.00000     16.751201
# ...     ...           ...           ...
# 1347  00241      12.46974      4.219508
# 1348    BOC       0.00000     13.331015
# 1349    BOC       0.00000      4.770685
# 1350    BOC       0.00000     11.841265
# 1351    BOC       0.00000      0.000000
#
# [1352 rows x 6 columns]

# %%
from collections import Counter
from sklearn import preprocessing
new_data = pd.DataFrame()
id_column = 'REQUEST_ID'
def get_info(df, new_df, column_name, column_type):
    if column_name == id_column:
        new_df[column_name] = df[column_name]
    else:  
        if column_type == 'categorical':
            df[column_name].fillna(f'NO_{column_name}',inplace=True)
            dict_ = {}
            a = Counter(df[column_name])     
            dict_['name'] = column_name
            dict_['size'] = len(a.keys())
            dict_['type'] = column_type
            enc=preprocessing.LabelEncoder()
            enc=enc.fit(list(a.keys()))#训练LabelEncoder,将电脑，手表，手机编码为0,1,2
            data=enc.transform(df[column_name])#使用训练好的LabelEncoder对原数据进行编码，也叫归一化
            dict_['i2s'] = list(enc.classes_)
            new_df[column_name] = data
            return dict_
        else:
            dict_ = {}
            dict_['max'] = max(df[column_name])
            dict_['min'] = min(df[column_name])
            dict_['name'] = column_name
            dict_['type'] = column_type
            new_df[column_name] = df[column_name]
            return dict_

# %%
new_data = pd.DataFrame()
a = ['activity', 'user']
b = ['waiting_time', 'process_time']
c = ['activity', 'user']

json_input = {}
get_info(file, new_data, 'REQUEST_ID', 'categorical')
json_input['attention'] = [get_info(file, new_data, each, 'categorical') for each in c]
json_input['columns'] = [get_info(file, new_data, each, 'categorical') for each in a]
json_input['columns'].extend([get_info(file, new_data, each, 'continuous') for each in b])
json_input['problem_type'] = 'no'

# %%
new_data['prev_acts'] = None
new_data['prev_res'] = None
new_data['curr_act'] = None
data_add_prev = pd.DataFrame()
for key, group in new_data.groupby('REQUEST_ID'):
    for i in range(len(group)):
        prev_acts = list(group['activity'].iloc[0:i].astype('str'))
        prev_acts_str = ' '.join(prev_acts)
        group['prev_acts'].iloc[i] = prev_acts_str
        
        prev_res = list(group['user'].iloc[0:i].astype('str'))
        prev_res_str = ' '.join(prev_res)
        group['prev_res'].iloc[i] = prev_res_str
        
        group['curr_act'].iloc[i] = group['activity'].iloc[i].astype('str')
    data_add_prev = pd.concat([data_add_prev, group])

# %%
new_data['prev_acts'] = None
new_data['prev_res'] = None
new_data['curr_act'] = None
data_add_prev = pd.DataFrame()
for key, group in new_data.groupby('REQUEST_ID'):
    for i in range(len(group)):
#         if i != 0:
        prev_acts = list(group['activity'].iloc[0:i])
#         prev_acts_str = ' '.join(prev_acts)
        group['prev_acts'].iloc[i] = prev_acts

        prev_res = list(group['user'].iloc[0:i])
#         prev_res_str = ' '.join(prev_res)
        group['prev_res'].iloc[i] = prev_res

        group['curr_act'].iloc[i] = [group['activity'].iloc[i]]
    data_add_prev = pd.concat([data_add_prev, group])

# %%
# data_add_prev = data_add_prev.dropna()

# %%
def padding(list_, pad_number, length):
    len_list = len(list_) 
    if len_list < length:
        list_ = list_+ (length - len_list)*[pad_number]
    return list_

def padding_key(list_,act_pad):
    return [True if each == act_pad else False for each in list_]

# %%
len_act = max(data_add_prev['prev_acts'].map(lambda x: len(x)))
len_res = max(data_add_prev['prev_res'].map(lambda x: len(x)))
act_pad = json_input['attention'][0]['size']
res_pad = json_input['attention'][1]['size']



data_add_prev['prev_acts'] = data_add_prev['prev_acts'].map(lambda x: padding(x,act_pad,len_act))
data_add_prev['prev_acts_key_padding'] = data_add_prev['prev_acts'].map(lambda x: padding_key(x,act_pad))
data_add_prev['prev_res'] = data_add_prev['prev_res'].map(lambda x: padding(x,res_pad,len_res))
data_add_prev['prev_res_key_padding'] = data_add_prev['prev_res'].map(lambda x: padding_key(x,res_pad))
json_input['attention'][0]['len'] = len_act
json_input['attention'][1]['len'] = len_res

# %%
data_add_prev
# Out:
#        REQUEST_ID  activity  user  waiting_time  process_time  \
# 714  201810001092        10   234           0.0      4.521789
# 715  201810001092        13   266           0.0      8.319717
# 716  201810001092         0   124           0.0     15.892016
# 717  201810001092        12   235           0.0     13.108737
# 718  201810001092         7   235           0.0      5.323010
# ..            ...       ...   ...           ...           ...
# 709   20192006829         0   173           0.0      5.111988
# 710   20192006829        12   235           0.0     12.455963
# 711   20192006829         7   235           0.0      3.178054
# 712   20192006829         5   235           0.0     11.801759
# 713   20192006829         9   235           0.0      0.000000
#
#                                             prev_acts  \
# 714  [14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14]
# 715  [10, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14]
# 716  [10, 13, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14]
# 717   [10, 13, 0, 14, 14, 14, 14, 14, 14, 14, 14, 14]
# 718   [10, 13, 0, 12, 14, 14, 14, 14, 14, 14, 14, 14]
# ..                                                ...
# 709  [10, 13, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14]
# 710   [10, 13, 0, 14, 14, 14, 14, 14, 14, 14, 14, 14]
# 711   [10, 13, 0, 12, 14, 14, 14, 14, 14, 14, 14, 14]
# 712    [10, 13, 0, 12, 7, 14, 14, 14, 14, 14, 14, 14]
# 713     [10, 13, 0, 12, 7, 5, 14, 14, 14, 14, 14, 14]
#
#                                               prev_res curr_act  \
# 714  [267, 267, 267, 267, 267, 267, 267, 267, 267, ...     [10]
# 715  [234, 267, 267, 267, 267, 267, 267, 267, 267, ...     [13]
# 716  [234, 266, 267, 267, 267, 267, 267, 267, 267, ...      [0]
# 717  [234, 266, 124, 267, 267, 267, 267, 267, 267, ...     [12]
# 718  [234, 266, 124, 235, 267, 267, 267, 267, 267, ...      [7]
# ..                                                 ...      ...
# 709  [246, 266, 267, 267, 267, 267, 267, 267, 267, ...      [0]
# 710  [246, 266, 173, 267, 267, 267, 267, 267, 267, ...     [12]
# 711  [246, 266, 173, 235, 267, 267, 267, 267, 267, ...      [7]
# 712  [246, 266, 173, 235, 235, 267, 267, 267, 267, ...      [5]
# 713  [246, 266, 173, 235, 235, 235, 267, 267, 267, ...      [9]
#
#                                  prev_acts_key_padding  \
# 714  [True, True, True, True, True, True, True, Tru...
# 715  [False, True, True, True, True, True, True, Tr...
# 716  [False, False, True, True, True, True, True, T...
# 717  [False, False, False, True, True, True, True, ...
# 718  [False, False, False, False, True, True, True,...
# ..                                                 ...
# 709  [False, False, True, True, True, True, True, T...
# 710  [False, False, False, True, True, True, True, ...
# 711  [False, False, False, False, True, True, True,...
# 712  [False, False, False, False, False, True, True...
# 713  [False, False, False, False, False, False, Tru...
#
#                                   prev_res_key_padding
# 714  [True, True, True, True, True, True, True, Tru...
# 715  [False, True, True, True, True, True, True, Tr...
# 716  [False, False, True, True, True, True, True, T...
# 717  [False, False, False, True, True, True, True, ...
# 718  [False, False, False, False, True, True, True,...
# ..                                                 ...
# 709  [False, False, True, True, True, True, True, T...
# 710  [False, False, False, True, True, True, True, ...
# 711  [False, False, False, False, True, True, True,...
# 712  [False, False, False, False, False, True, True...
# 713  [False, False, False, False, False, False, Tru...
#
# [1352 rows x 10 columns]

# %%
data = data_add_prev[['activity', 'user', 'waiting_time', 'process_time', 'prev_acts', 'prev_res','prev_acts_key_padding','prev_res_key_padding', 'curr_act']]
data = data.reset_index(drop = True)
data
# Out:
#       activity  user  waiting_time  process_time  \
# 0           10   234           0.0      4.521789
# 1           13   266           0.0      8.319717
# 2            0   124           0.0     15.892016
# 3           12   235           0.0     13.108737
# 4            7   235           0.0      5.323010
# ...        ...   ...           ...           ...
# 1347         0   173           0.0      5.111988
# 1348        12   235           0.0     12.455963
# 1349         7   235           0.0      3.178054
# 1350         5   235           0.0     11.801759
# 1351         9   235           0.0      0.000000
#
#                                              prev_acts  \
# 0     [14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14]
# 1     [10, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14]
# 2     [10, 13, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14]
# 3      [10, 13, 0, 14, 14, 14, 14, 14, 14, 14, 14, 14]
# 4      [10, 13, 0, 12, 14, 14, 14, 14, 14, 14, 14, 14]
# ...                                                ...
# 1347  [10, 13, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14]
# 1348   [10, 13, 0, 14, 14, 14, 14, 14, 14, 14, 14, 14]
# 1349   [10, 13, 0, 12, 14, 14, 14, 14, 14, 14, 14, 14]
# 1350    [10, 13, 0, 12, 7, 14, 14, 14, 14, 14, 14, 14]
# 1351     [10, 13, 0, 12, 7, 5, 14, 14, 14, 14, 14, 14]
#
#                                                prev_res  \
# 0     [267, 267, 267, 267, 267, 267, 267, 267, 267, ...
# 1     [234, 267, 267, 267, 267, 267, 267, 267, 267, ...
# 2     [234, 266, 267, 267, 267, 267, 267, 267, 267, ...
# 3     [234, 266, 124, 267, 267, 267, 267, 267, 267, ...
# 4     [234, 266, 124, 235, 267, 267, 267, 267, 267, ...
# ...                                                 ...
# 1347  [246, 266, 267, 267, 267, 267, 267, 267, 267, ...
# 1348  [246, 266, 173, 267, 267, 267, 267, 267, 267, ...
# 1349  [246, 266, 173, 235, 267, 267, 267, 267, 267, ...
# 1350  [246, 266, 173, 235, 235, 267, 267, 267, 267, ...
# 1351  [246, 266, 173, 235, 235, 235, 267, 267, 267, ...
#
#                                   prev_acts_key_padding  \
# 0     [True, True, True, True, True, True, True, Tru...
# 1     [False, True, True, True, True, True, True, Tr...
# 2     [False, False, True, True, True, True, True, T...
# 3     [False, False, False, True, True, True, True, ...
# 4     [False, False, False, False, True, True, True,...
# ...                                                 ...
# 1347  [False, False, True, True, True, True, True, T...
# 1348  [False, False, False, True, True, True, True, ...
# 1349  [False, False, False, False, True, True, True,...
# 1350  [False, False, False, False, False, True, True...
# 1351  [False, False, False, False, False, False, Tru...
#
#                                    prev_res_key_padding curr_act
# 0     [True, True, True, True, True, True, True, Tru...     [10]
# 1     [False, True, True, True, True, True, True, Tr...     [13]
# 2     [False, False, True, True, True, True, True, T...      [0]
# 3     [False, False, False, True, True, True, True, ...     [12]
# 4     [False, False, False, False, True, True, True,...      [7]
# ...                                                 ...      ...
# 1347  [False, False, True, True, True, True, True, T...      [0]
# 1348  [False, False, False, True, True, True, True, ...     [12]
# 1349  [False, False, False, False, True, True, True,...      [7]
# 1350  [False, False, False, False, False, True, True...      [5]
# 1351  [False, False, False, False, False, False, Tru...      [9]
#
# [1352 rows x 9 columns]

# %%
num_train = round(len(data)*0.8)
num_train
# Out:
# 1082

# %%
from torch.utils.data import DataLoader
def infiniteloop(dataloader):
    while True:
        for _, y in enumerate(dataloader):
            yield y
            
# print(train_attention.tolist())
a = DataLoader(train_attention.tolist(),batch_size=5)
b = infiniteloop(a)
next(b)
# Out:
# [[tensor([14, 10, 10, 10, 10]),
#   tensor([14, 14, 13, 13, 13]),
#   tensor([14, 14, 14,  0,  0]),
#   tensor([14, 14, 14, 14, 12]),
#   tensor([14, 14, 14, 14, 14]),
#   tensor([14, 14, 14, 14, 14]),
#   tensor([14, 14, 14, 14, 14]),
#   tensor([14, 14, 14, 14, 14]),
#   tensor([14, 14, 14, 14, 14]),
#   tensor([14, 14, 14, 14, 14]),
#   tensor([14, 14, 14, 14, 14]),
#   tensor([14, 14, 14, 14, 14])],
#  [tensor([267, 234, 234, 234, 234]),
#   tensor([267, 267, 266, 266, 266]),
#   tensor([267, 267, 267, 124, 124]),
#   tensor([267, 267, 267, 267, 235]),
#   tensor([267, 267, 267, 267, 267]),
#   tensor([267, 267, 267, 267, 267]),
#   tensor([267, 267, 267, 267, 267]),
#   tensor([267, 267, 267, 267, 267]),
#   tensor([267, 267, 267, 267, 267]),
#   tensor([267, 267, 267, 267, 267]),
#   tensor([267, 267, 267, 267, 267]),
#   tensor([267, 267, 267, 267, 267])],
#  [tensor([10, 13,  0, 12,  7], dtype=torch.int32)]]

# %%
import json
with open("res_time_prev.json","w") as f:
    json.dump(json_input,f)

# with open('test.json') as json_file:
#     a = json.load(json_file)

train = np.array(data.iloc[:num_train])
train_1 = train[:,0:-5].astype('float32')
train_attention = train[:,-5:]
train

test = np.array(data.iloc[num_train:])
test_1 = test[:,0:-5].astype('float32')
test_attention = test[:,-5:]
test.shape
train_1


array_dict = {'train':train_1, 'test':test_1, 'train_attention': train_attention, 'test_attention' :test_attention}
np.savez('res_time_prev.npz', **array_dict)

# %%
a = np.load('res_time_prev.npz',allow_pickle=True)
a['train'].shape
# Out:
# (1082, 3)

# %%
# !pip install torchtext==0.6.0
# Out:
# Requirement already satisfied: torchtext==0.6.0 in c:\users\19wuj\anaconda3\lib\site-packages (0.6.0)
# Requirement already satisfied: tqdm in c:\users\19wuj\anaconda3\lib\site-packages (from torchtext==0.6.0) (4.65.0)
# Requirement already satisfied: requests in c:\users\19wuj\appdata\roaming\python\python37\site-packages (from torchtext==0.6.0) (2.26.0)
# Requirement already satisfied: torch in c:\users\19wuj\anaconda3\lib\site-packages (from torchtext==0.6.0) (1.13.1)
# Requirement already satisfied: numpy in c:\users\19wuj\anaconda3\lib\site-packages (from torchtext==0.6.0) (1.19.5)
# Requirement already satisfied: six in c:\users\19wuj\appdata\roaming\python\python37\site-packages (from torchtext==0.6.0) (1.16.0)
# Requirement already satisfied: sentencepiece in c:\users\19wuj\anaconda3\lib\site-packages (from torchtext==0.6.0) (0.1.99)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\19wuj\appdata\roaming\python\python37\site-packages (from requests->torchtext==0.6.0) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\19wuj\appdata\roaming\python\python37\site-packages (from requests->torchtext==0.6.0) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\19wuj\appdata\roaming\python\python37\site-packages (from requests->torchtext==0.6.0) (2.0.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\19wuj\appdata\roaming\python\python37\site-packages (from requests->torchtext==0.6.0) (3.3)
# Requirement already satisfied: typing-extensions in c:\users\19wuj\anaconda3\lib\site-packages (from torch->torchtext==0.6.0) (4.5.0)
# Requirement already satisfied: colorama in c:\users\19wuj\anaconda3\lib\site-packages (from tqdm->torchtext==0.6.0) (0.3.9)
# WARNING: Ignoring invalid distribution -andas (c:\users\19wuj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\19wuj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\19wuj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\19wuj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\19wuj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\19wuj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\19wuj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\19wuj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\19wuj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\19wuj\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from torchtext.vocab import Vocab,build_vocab_from_iterator

from collections import Counter, OrderedDict
import torch

# %%
gen_act
# Out:
# 0                                         Start
# 1                               Request created
# 2       Pending Request for Network Information
# 3       Pending Request for Reservation Closure
# 4                   Pending Liquidation Request
#                          ...
# 347     Pending Request for Reservation Closure
# 348                 Pending Liquidation Request
# 349    Pending Request for acquittance of heirs
# 350      Request completed with account closure
# 351                                         End
# Name: act, Length: 352, dtype: object

# %%
import pandas as pd
import numpy as np
gen = pd.read_csv('new_technique_train_bac_cut_time.csv')
gen_act = gen['act']
gen_act = gen_act.map(lambda x:json_input['columns'][0]['i2s'].index(x))
gen_act = np.array(gen_act).astype('float32')
gen_act

array_dict = {'gen':gen_act}
np.savez('gen_bac_act_time.npz', **array_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-427-aee45e33ac66> in <module>()
#       3 gen = pd.read_csv('new_technique_train_bac_cut_time.csv')
#       4 gen_act = gen['act']
# ----> 5 gen_act = gen_act.map(lambda x:json_input['columns'][0]['i2s'].index(x))
#       6 gen_act = np.array(gen_act).astype('float32')
#       7 gen_act
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    3981         dtype: object
#    3982         """
# -> 3983         new_values = super()._map_values(arg, na_action=na_action)
#    3984         return self._constructor(new_values, index=self.index).__finalize__(
#    3985             self, method="map"
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#    1158
#    1159         # mapper is a function
# -> 1160         new_values = map_f(values, mapper)
#    1161
#    1162         return new_values
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-427-aee45e33ac66> in <lambda>(x)
#       3 gen = pd.read_csv('new_technique_train_bac_cut_time.csv')
#       4 gen_act = gen['act']
# ----> 5 gen_act = gen_act.map(lambda x:json_input['columns'][0]['i2s'].index(x))
#       6 gen_act = np.array(gen_act).astype('float32')
#       7 gen_act
#
# ValueError: 'Start' is not in list

# %%
act_vocab = build_vocab(column='activity', min_freq=1)
act_vocab.get_stoi()
# Out:
# {'<bos>': 2,
#  'Pending_Request_for_Reservation_Closure': 6,
#  '<unk>': 0,
#  'Request_created': 4,
#  '<eos>': 3,
#  '<pad>': 1,
#  'Service_closure_Request_with_BO_responsibility': 5,
#  'Pending_Request_for_acquittance_of_heirs': 12,
#  'Request_completed_with_account_closure': 7,
#  'Pending_Liquidation_Request': 8,
#  'Service_closure_Request_with_network_responsibility': 9,
#  'Authorization_Requested': 10,
#  'Request_deleted': 14,
#  'Evaluating_Request_(NO_registered_letter)': 11,
#  'Network_Adjustment_Requested': 13,
#  'Back-Office_Adjustment_Requested': 15,
#  'Pending_Request_for_Network_Information': 16,
#  'Evaluating_Request_(WITH_registered_letter)': 17}

# %%
class LoadActResDataset():
    def __init__(self, batch_size=2, min_freq=1):
        self.act_vocab = build_vocab(column='activity', min_freq=min_freq)
        self.res_vocab = build_vocab(column='user', min_freq=min_freq)
        self.specials = ['<unk>', '<pad>', '<bos>', '<eos>']
        self.PAD_IDX = self.act_vocab['<pad>']
        self.BOS_IDX = self.act_vocab['<bos>']
        self.EOS_IDX = self.act_vocab['<eos>']
        self.batch_size = batch_size
        
    def data_process(self):
        """
        将每一句话中的每一个词根据字典转换成索引的形式
        :param filepaths:
        :return:
        """
        raw_act_iter = data_add_prev['prev_acts']
        raw_res_iter = data_add_prev['prev_res']
        raw_curr_act_iter = data_add_prev['curr_act']
        data = []
        for (raw_act, raw_res, curr_act) in zip(raw_act_iter, raw_res_iter, raw_curr_act_iter):
            act_tensor_ = torch.tensor([self.act_vocab[token] for token in
                                       raw_act], dtype=torch.long)
            res_tensor_ = torch.tensor([self.res_vocab[token] for token in
                                       raw_res], dtype=torch.long)
            curr_act_tensor_ = torch.tensor([self.act_vocab[token] for token in
                                       curr_act], dtype=torch.long)
            data.append((act_tensor_, res_tensor_, curr_act_tensor_))
        return data

# %%
d = LoadActResDataset()
d.data_process()
# Out:
# [(tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([258]), tensor([9])),
#  (tensor([4, 9]), tensor([258,   5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([258,   5, 204]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([258,   5, 204,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([258,   5, 204,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([258,   5, 204,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([151]), tensor([11])),
#  (tensor([ 4, 11]), tensor([151,  64]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([151,  64,  64]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([151,  64,  64,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([151,  64,  64,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([151,  64,  64,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([195]), tensor([16])),
#  (tensor([ 4, 16]), tensor([195,   6]), tensor([6])),
#  (tensor([ 4, 16,  6]), tensor([195,   6,   6]), tensor([8])),
#  (tensor([ 4, 16,  6,  8]), tensor([195,   6,   6,   6]), tensor([15])),
#  (tensor([ 4, 16,  6,  8, 15]),
#   tensor([195,   6,   6,   6,   6]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([125]), tensor([11])),
#  (tensor([ 4, 11]), tensor([125,  20]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([125,  20,  20]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([125,  20,  20,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([125,  20,  20,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([125,  20,  20,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([248]), tensor([11])),
#  (tensor([ 4, 11]), tensor([248, 119]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([248, 119, 119]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([248, 119, 119,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([248, 119, 119,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([248, 119, 119,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([49]), tensor([9])),
#  (tensor([4, 9]), tensor([49,  5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([49,  5, 39]), tensor([13])),
#  (tensor([ 4,  9, 10, 13]), tensor([49,  5, 39, 39]), tensor([10])),
#  (tensor([ 4,  9, 10, 13, 10]), tensor([49,  5, 39, 39, 39]), tensor([5])),
#  (tensor([ 4,  9, 10, 13, 10,  5]),
#   tensor([49,  5, 39, 39, 39,  4]),
#   tensor([6])),
#  (tensor([ 4,  9, 10, 13, 10,  5,  6]),
#   tensor([49,  5, 39, 39, 39,  4,  4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10, 13, 10,  5,  6,  8]),
#   tensor([49,  5, 39, 39, 39,  4,  4,  4]),
#   tensor([12])),
#  (tensor([ 4,  9, 10, 13, 10,  5,  6,  8, 12]),
#   tensor([49,  5, 39, 39, 39,  4,  4,  4,  4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([188]), tensor([9])),
#  (tensor([4, 9]), tensor([188,   5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([188,   5,  58]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([188,   5,  58,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([188,   5,  58,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([188,   5,  58,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([165]), tensor([9])),
#  (tensor([4, 9]), tensor([165,   5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([165,   5, 267]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([165,   5, 267,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([165,   5, 267,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([165,   5, 267,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([228]), tensor([16])),
#  (tensor([ 4, 16]), tensor([228,   6]), tensor([14])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([202]), tensor([11])),
#  (tensor([ 4, 11]), tensor([202, 102]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([202, 102, 102]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([202, 102, 102,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([202, 102, 102,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([202, 102, 102,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([30]), tensor([11])),
#  (tensor([ 4, 11]), tensor([30, 48]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([30, 48, 48]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([30, 48, 48,  4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]), tensor([30, 48, 48,  4,  4]), tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([30, 48, 48,  4,  4,  4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([193]), tensor([11])),
#  (tensor([ 4, 11]), tensor([193,  33]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([193,  33,  33]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([193,  33,  33,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([193,  33,  33,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([193,  33,  33,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([168]), tensor([9])),
#  (tensor([4, 9]), tensor([168,   5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([168,   5,  61]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([168,   5,  61,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([168,   5,  61,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([168,   5,  61,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([137]), tensor([11])),
#  (tensor([ 4, 11]), tensor([137,  86]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([137,  86,  86]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([137,  86,  86,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([137,  86,  86,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([137,  86,  86,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([232]), tensor([9])),
#  (tensor([4, 9]), tensor([232,   5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([232,   5, 253]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([232,   5, 253,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([232,   5, 253,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([232,   5, 253,   4,   4,   4]),
#   tensor([12])),
#  (tensor([ 4,  9, 10,  5,  6,  8, 12]),
#   tensor([232,   5, 253,   4,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([117]), tensor([9])),
#  (tensor([4, 9]), tensor([117,   5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([117,   5,  30]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([117,   5,  30,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([117,   5,  30,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([117,   5,  30,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([35]), tensor([11])),
#  (tensor([ 4, 11]), tensor([35, 34]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([35, 34, 34]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([35, 34, 34,  4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]), tensor([35, 34, 34,  4,  4]), tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([35, 34, 34,  4,  4,  4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([114]), tensor([11])),
#  (tensor([ 4, 11]), tensor([114, 106]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([114, 106, 106]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([114, 106, 106,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([114, 106, 106,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([114, 106, 106,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([44]), tensor([11])),
#  (tensor([ 4, 11]), tensor([44, 10]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([44, 10, 10]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([44, 10, 10,  4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]), tensor([44, 10, 10,  4,  4]), tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([44, 10, 10,  4,  4,  4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([63]), tensor([16])),
#  (tensor([ 4, 16]), tensor([63,  7]), tensor([14])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([216]), tensor([11])),
#  (tensor([ 4, 11]), tensor([216, 128]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([216, 128, 128]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([216, 128, 128,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([216, 128, 128,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([216, 128, 128,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([239]), tensor([11])),
#  (tensor([ 4, 11]), tensor([239,  12]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([239,  12,  12]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([239,  12,  12,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([239,  12,  12,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([239,  12,  12,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([60]), tensor([9])),
#  (tensor([4, 9]), tensor([60,  5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([60,  5, 82]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([60,  5, 82,  4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]), tensor([60,  5, 82,  4,  4]), tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([60,  5, 82,  4,  4,  4]),
#   tensor([12])),
#  (tensor([ 4,  9, 10,  5,  6,  8, 12]),
#   tensor([60,  5, 82,  4,  4,  4,  4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([225]), tensor([11])),
#  (tensor([ 4, 11]), tensor([225,  21]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([225,  21,  21]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([225,  21,  21,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([225,  21,  21,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([225,  21,  21,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([68]), tensor([9])),
#  (tensor([4, 9]), tensor([68,  5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([ 68,   5, 139]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([ 68,   5, 139,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([ 68,   5, 139,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([ 68,   5, 139,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([206]), tensor([11])),
#  (tensor([ 4, 11]), tensor([206,  36]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([206,  36,  36]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([206,  36,  36,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([206,  36,  36,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([206,  36,  36,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([47]), tensor([9])),
#  (tensor([4, 9]), tensor([47,  5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([ 47,   5, 242]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([ 47,   5, 242,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([ 47,   5, 242,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([ 47,   5, 242,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([230]), tensor([9])),
#  (tensor([4, 9]), tensor([230,   5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([230,   5,   9]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([230,   5,   9,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([230,   5,   9,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([230,   5,   9,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([266]), tensor([16])),
#  (tensor([ 4, 16]), tensor([266,   6]), tensor([6])),
#  (tensor([ 4, 16,  6]), tensor([266,   6,   6]), tensor([8])),
#  (tensor([ 4, 16,  6,  8]), tensor([266,   6,   6,   6]), tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([9]), tensor([11])),
#  (tensor([ 4, 11]), tensor([9, 9]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([9, 9, 9]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([9, 9, 9, 4]), tensor([13])),
#  (tensor([ 4, 11,  9,  5, 13]), tensor([9, 9, 9, 4, 9]), tensor([5])),
#  (tensor([ 4, 11,  9,  5, 13,  5]), tensor([9, 9, 9, 4, 9, 4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5, 13,  5,  6]),
#   tensor([9, 9, 9, 4, 9, 4, 4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5, 13,  5,  6,  8]),
#   tensor([9, 9, 9, 4, 9, 4, 4, 4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([26]), tensor([9])),
#  (tensor([4, 9]), tensor([26,  5]), tensor([5])),
#  (tensor([4, 9, 5]), tensor([26,  5,  4]), tensor([6])),
#  (tensor([4, 9, 5, 6]), tensor([26,  5,  4,  4]), tensor([8])),
#  (tensor([4, 9, 5, 6, 8]), tensor([26,  5,  4,  4,  4]), tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([53]), tensor([11])),
#  (tensor([ 4, 11]), tensor([53, 83]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([53, 83, 83]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([53, 83, 83,  4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]), tensor([53, 83, 83,  4,  4]), tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([53, 83, 83,  4,  4,  4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([146]), tensor([11])),
#  (tensor([ 4, 11]), tensor([146,  41]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([146,  41,  41]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([146,  41,  41,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([146,  41,  41,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([146,  41,  41,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([164]), tensor([11])),
#  (tensor([ 4, 11]), tensor([164,  28]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([164,  28,  28]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([164,  28,  28,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([164,  28,  28,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([164,  28,  28,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([249]), tensor([16])),
#  (tensor([ 4, 16]), tensor([249,   6]), tensor([6])),
#  (tensor([ 4, 16,  6]), tensor([249,   6,   6]), tensor([8])),
#  (tensor([ 4, 16,  6,  8]), tensor([249,   6,   6,   6]), tensor([15])),
#  (tensor([ 4, 16,  6,  8, 15]),
#   tensor([249,   6,   6,   6,   6]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([135]), tensor([11])),
#  (tensor([ 4, 11]), tensor([135,  52]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([135,  52,  52]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([135,  52,  52,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([135,  52,  52,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([135,  52,  52,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([208]), tensor([9])),
#  (tensor([4, 9]), tensor([208,   5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([208,   5,  61]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([208,   5,  61,   4]), tensor([13])),
#  (tensor([ 4,  9, 10,  5, 13]),
#   tensor([208,   5,  61,   4,  61]),
#   tensor([5])),
#  (tensor([ 4,  9, 10,  5, 13,  5]),
#   tensor([208,   5,  61,   4,  61,   4]),
#   tensor([6])),
#  (tensor([ 4,  9, 10,  5, 13,  5,  6]),
#   tensor([208,   5,  61,   4,  61,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5, 13,  5,  6,  8]),
#   tensor([208,   5,  61,   4,  61,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([122]), tensor([11])),
#  (tensor([ 4, 11]), tensor([122,  25]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([122,  25,  25]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([122,  25,  25,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([122,  25,  25,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([122,  25,  25,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([243]), tensor([11])),
#  (tensor([ 4, 11]), tensor([243, 104]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([243, 104, 104]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([243, 104, 104,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([243, 104, 104,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([243, 104, 104,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([161]), tensor([11])),
#  (tensor([ 4, 11]), tensor([161,  12]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([161,  12,  12]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([161,  12,  12,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([161,  12,  12,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([161,  12,  12,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([214]), tensor([11])),
#  (tensor([ 4, 11]), tensor([214, 121]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([214, 121, 121]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([214, 121, 121,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([214, 121, 121,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([214, 121, 121,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([231]), tensor([11])),
#  (tensor([ 4, 11]), tensor([231,  17]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([231,  17,  17]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([231,  17,  17,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([231,  17,  17,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([231,  17,  17,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([47]), tensor([14])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([131]), tensor([16])),
#  (tensor([ 4, 16]), tensor([131,   7]), tensor([6])),
#  (tensor([ 4, 16,  6]), tensor([131,   7,   7]), tensor([8])),
#  (tensor([ 4, 16,  6,  8]), tensor([131,   7,   7,   7]), tensor([15])),
#  (tensor([ 4, 16,  6,  8, 15]),
#   tensor([131,   7,   7,   7,   7]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([219]), tensor([11])),
#  (tensor([ 4, 11]), tensor([219,  69]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([219,  69,  69]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([219,  69,  69,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([219,  69,  69,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([219,  69,  69,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([45]), tensor([9])),
#  (tensor([4, 9]), tensor([45,  5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([45,  5, 65]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([45,  5, 65,  4]), tensor([13])),
#  (tensor([ 4,  9, 10,  5, 13]), tensor([45,  5, 65,  4, 65]), tensor([5])),
#  (tensor([ 4,  9, 10,  5, 13,  5]),
#   tensor([45,  5, 65,  4, 65,  4]),
#   tensor([6])),
#  (tensor([ 4,  9, 10,  5, 13,  5,  6]),
#   tensor([45,  5, 65,  4, 65,  4,  4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5, 13,  5,  6,  8]),
#   tensor([45,  5, 65,  4, 65,  4,  4,  4]),
#   tensor([12])),
#  (tensor([ 4,  9, 10,  5, 13,  5,  6,  8, 12]),
#   tensor([45,  5, 65,  4, 65,  4,  4,  4,  4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([182]), tensor([5])),
#  (tensor([4, 5]), tensor([182,   5]), tensor([6])),
#  (tensor([4, 5, 6]), tensor([182,   5,   8]), tensor([8])),
#  (tensor([4, 5, 6, 8]), tensor([182,   5,   8,   8]), tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([14]), tensor([9])),
#  (tensor([4, 9]), tensor([14,  5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([ 14,   5, 268]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([ 14,   5, 268,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([ 14,   5, 268,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([ 14,   5, 268,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([36]), tensor([9])),
#  (tensor([4, 9]), tensor([36,  5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([36,  5, 24]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([36,  5, 24,  4]), tensor([13])),
#  (tensor([ 4,  9, 10,  5, 13]), tensor([36,  5, 24,  4, 24]), tensor([5])),
#  (tensor([ 4,  9, 10,  5, 13,  5]),
#   tensor([36,  5, 24,  4, 24,  4]),
#   tensor([13])),
#  (tensor([ 4,  9, 10,  5, 13,  5, 13]),
#   tensor([36,  5, 24,  4, 24,  4, 24]),
#   tensor([5])),
#  (tensor([ 4,  9, 10,  5, 13,  5, 13,  5]),
#   tensor([36,  5, 24,  4, 24,  4, 24,  4]),
#   tensor([13])),
#  (tensor([ 4,  9, 10,  5, 13,  5, 13,  5, 13]),
#   tensor([36,  5, 24,  4, 24,  4, 24,  4, 24]),
#   tensor([5])),
#  (tensor([ 4,  9, 10,  5, 13,  5, 13,  5, 13,  5]),
#   tensor([36,  5, 24,  4, 24,  4, 24,  4, 24,  4]),
#   tensor([6])),
#  (tensor([ 4,  9, 10,  5, 13,  5, 13,  5, 13,  5,  6]),
#   tensor([36,  5, 24,  4, 24,  4, 24,  4, 24,  4,  4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5, 13,  5, 13,  5, 13,  5,  6,  8]),
#   tensor([36,  5, 24,  4, 24,  4, 24,  4, 24,  4,  4,  4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([252]), tensor([11])),
#  (tensor([ 4, 11]), tensor([252,  20]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([252,  20,  20]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([252,  20,  20,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([252,  20,  20,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([252,  20,  20,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([159]), tensor([9])),
#  (tensor([4, 9]), tensor([159,   5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([159,   5,  50]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([159,   5,  50,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([159,   5,  50,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([159,   5,  50,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([115]), tensor([9])),
#  (tensor([4, 9]), tensor([115,   5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([115,   5, 244]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([115,   5, 244,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([115,   5, 244,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([115,   5, 244,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([224]), tensor([16])),
#  (tensor([ 4, 16]), tensor([224,   7]), tensor([6])),
#  (tensor([ 4, 16,  6]), tensor([224,   7,   7]), tensor([8])),
#  (tensor([ 4, 16,  6,  8]), tensor([224,   7,   7,   7]), tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([203]), tensor([11])),
#  (tensor([ 4, 11]), tensor([203,  49]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([203,  49,  49]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([203,  49,  49,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([203,  49,  49,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([203,  49,  49,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([236]), tensor([11])),
#  (tensor([ 4, 11]), tensor([236,  29]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([236,  29,  29]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([236,  29,  29,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([236,  29,  29,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([236,  29,  29,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([157]), tensor([5])),
#  (tensor([4, 5]), tensor([157,   5]), tensor([6])),
#  (tensor([4, 5, 6]), tensor([157,   5,   8]), tensor([8])),
#  (tensor([4, 5, 6, 8]), tensor([157,   5,   8,   8]), tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([82]), tensor([14])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([85]), tensor([11])),
#  (tensor([ 4, 11]), tensor([85, 40]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([85, 40, 40]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([85, 40, 40,  4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]), tensor([85, 40, 40,  4,  4]), tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([85, 40, 40,  4,  4,  4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([147]), tensor([11])),
#  (tensor([ 4, 11]), tensor([147, 112]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([147, 112, 112]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([147, 112, 112,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([147, 112, 112,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([147, 112, 112,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([130]), tensor([5])),
#  (tensor([4, 5]), tensor([130,   4]), tensor([6])),
#  (tensor([4, 5, 6]), tensor([130,   4,   4]), tensor([8])),
#  (tensor([4, 5, 6, 8]), tensor([130,   4,   4,   4]), tensor([15])),
#  (tensor([ 4,  5,  6,  8, 15]),
#   tensor([130,   4,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([180]), tensor([11])),
#  (tensor([ 4, 11]), tensor([180,  18]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([180,  18,  18]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([180,  18,  18,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([180,  18,  18,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([180,  18,  18,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([175]), tensor([5])),
#  (tensor([4, 5]), tensor([175,   4]), tensor([6])),
#  (tensor([4, 5, 6]), tensor([175,   4,   4]), tensor([8])),
#  (tensor([4, 5, 6, 8]), tensor([175,   4,   4,   4]), tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([133]), tensor([17])),
#  (tensor([ 4, 17]), tensor([133,  43]), tensor([9])),
#  (tensor([ 4, 17,  9]), tensor([133,  43,  43]), tensor([5])),
#  (tensor([ 4, 17,  9,  5]), tensor([133,  43,  43,   4]), tensor([6])),
#  (tensor([ 4, 17,  9,  5,  6]),
#   tensor([133,  43,  43,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 17,  9,  5,  6,  8]),
#   tensor([133,  43,  43,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([166]), tensor([11])),
#  (tensor([ 4, 11]), tensor([166, 107]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([166, 107, 107]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([166, 107, 107,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([166, 107, 107,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([166, 107, 107,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([51]), tensor([14])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([54]), tensor([11])),
#  (tensor([ 4, 11]), tensor([54, 13]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([54, 13, 13]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([54, 13, 13,  4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]), tensor([54, 13, 13,  4,  4]), tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([54, 13, 13,  4,  4,  4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([246]), tensor([5])),
#  (tensor([4, 5]), tensor([246,   4]), tensor([6])),
#  (tensor([4, 5, 6]), tensor([246,   4,   4]), tensor([8])),
#  (tensor([4, 5, 6, 8]), tensor([246,   4,   4,   4]), tensor([15])),
#  (tensor([ 4,  5,  6,  8, 15]),
#   tensor([246,   4,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([55]), tensor([9])),
#  (tensor([4, 9]), tensor([55,  5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([ 55,   5, 215]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([ 55,   5, 215,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([ 55,   5, 215,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([ 55,   5, 215,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([189]), tensor([17])),
#  (tensor([ 4, 17]), tensor([189,  73]), tensor([9])),
#  (tensor([ 4, 17,  9]), tensor([189,  73,  73]), tensor([5])),
#  (tensor([ 4, 17,  9,  5]), tensor([189,  73,  73,   4]), tensor([6])),
#  (tensor([ 4, 17,  9,  5,  6]),
#   tensor([189,  73,  73,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 17,  9,  5,  6,  8]),
#   tensor([189,  73,  73,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([80]), tensor([11])),
#  (tensor([ 4, 11]), tensor([80, 31]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([80, 31, 31]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([80, 31, 31,  4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]), tensor([80, 31, 31,  4,  4]), tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([80, 31, 31,  4,  4,  4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([111]), tensor([14])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([7]), tensor([11])),
#  (tensor([ 4, 11]), tensor([ 7, 29]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([ 7, 29, 29]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([ 7, 29, 29,  4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]), tensor([ 7, 29, 29,  4,  4]), tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([ 7, 29, 29,  4,  4,  4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([229]), tensor([14])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([79]), tensor([9])),
#  (tensor([4, 9]), tensor([79,  5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([ 79,   5, 150]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([ 79,   5, 150,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([ 79,   5, 150,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([ 79,   5, 150,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([176]), tensor([9])),
#  (tensor([4, 9]), tensor([176,   5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([176,   5,  84]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([176,   5,  84,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([176,   5,  84,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([176,   5,  84,   4,   4,   4]),
#   tensor([15])),
#  (tensor([ 4,  9, 10,  5,  6,  8, 15]),
#   tensor([176,   5,  84,   4,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([153]), tensor([11])),
#  (tensor([ 4, 11]), tensor([153,  17]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([153,  17,  17]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([153,  17,  17,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([153,  17,  17,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([153,  17,  17,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([197]), tensor([9])),
#  (tensor([4, 9]), tensor([197,   5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([197,   5,  94]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([197,   5,  94,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([197,   5,  94,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([197,   5,  94,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([149]), tensor([9])),
#  (tensor([4, 9]), tensor([149,   5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([149,   5, 101]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([149,   5, 101,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([149,   5, 101,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([149,   5, 101,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([156]), tensor([9])),
#  (tensor([4, 9]), tensor([156,   5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([156,   5, 142]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([156,   5, 142,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([156,   5, 142,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([156,   5, 142,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([35]), tensor([9])),
#  (tensor([4, 9]), tensor([35,  5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([35,  5, 11]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([35,  5, 11,  4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]), tensor([35,  5, 11,  4,  4]), tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([35,  5, 11,  4,  4,  4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([93]), tensor([11])),
#  (tensor([ 4, 11]), tensor([ 93, 123]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([ 93, 123, 123]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([ 93, 123, 123,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([ 93, 123, 123,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([ 93, 123, 123,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([269]), tensor([11])),
#  (tensor([ 4, 11]), tensor([269,  37]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([269,  37,  37]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([269,  37,  37,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([269,  37,  37,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([269,  37,  37,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([80]), tensor([9])),
#  (tensor([4, 9]), tensor([80,  5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([80,  5, 81]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([80,  5, 81,  4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]), tensor([80,  5, 81,  4,  4]), tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([80,  5, 81,  4,  4,  4]),
#   tensor([12])),
#  (tensor([ 4,  9, 10,  5,  6,  8, 12]),
#   tensor([80,  5, 81,  4,  4,  4,  4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([35]), tensor([11])),
#  (tensor([ 4, 11]), tensor([35, 27]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([35, 27, 27]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([35, 27, 27,  4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]), tensor([35, 27, 27,  4,  4]), tensor([15])),
#  (tensor([ 4, 11,  9,  5,  6, 15]),
#   tensor([35, 27, 27,  4,  4,  4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([207]), tensor([11])),
#  (tensor([ 4, 11]), tensor([207,  62]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([207,  62,  62]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([207,  62,  62,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([207,  62,  62,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([207,  62,  62,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([136]), tensor([11])),
#  (tensor([ 4, 11]), tensor([136,  25]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([136,  25,  25]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([136,  25,  25,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([136,  25,  25,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([136,  25,  25,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([241]), tensor([11])),
#  (tensor([ 4, 11]), tensor([241,  10]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([241,  10,  10]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([241,  10,  10,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([241,  10,  10,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([241,  10,  10,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([136]), tensor([11])),
#  (tensor([ 4, 11]), tensor([136,  92]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([136,  92,  92]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([136,  92,  92,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([136,  92,  92,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([136,  92,  92,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([185]), tensor([14])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([34]), tensor([9])),
#  (tensor([4, 9]), tensor([34,  5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([ 34,   5, 115]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([ 34,   5, 115,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([ 34,   5, 115,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([ 34,   5, 115,   4,   4,   4]),
#   tensor([15])),
#  (tensor([ 4,  9, 10,  5,  6,  8, 15]),
#   tensor([ 34,   5, 115,   4,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([63]), tensor([14])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([222]), tensor([9])),
#  (tensor([4, 9]), tensor([222,   5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([222,   5,  59]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([222,   5,  59,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([222,   5,  59,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([222,   5,  59,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([84]), tensor([5])),
#  (tensor([4, 5]), tensor([84,  4]), tensor([6])),
#  (tensor([4, 5, 6]), tensor([84,  4,  4]), tensor([8])),
#  (tensor([4, 5, 6, 8]), tensor([84,  4,  4,  4]), tensor([15])),
#  (tensor([ 4,  5,  6,  8, 15]), tensor([84,  4,  4,  4,  4]), tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([95]), tensor([11])),
#  (tensor([ 4, 11]), tensor([95, 91]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([95, 91, 91]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([95, 91, 91,  4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]), tensor([95, 91, 91,  4,  4]), tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([95, 91, 91,  4,  4,  4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([6]), tensor([11])),
#  (tensor([ 4, 11]), tensor([ 6, 10]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([ 6, 10, 10]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([ 6, 10, 10,  4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]), tensor([ 6, 10, 10,  4,  4]), tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([ 6, 10, 10,  4,  4,  4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([213]), tensor([11])),
#  (tensor([ 4, 11]), tensor([213,  99]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([213,  99,  99]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([213,  99,  99,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([213,  99,  99,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([213,  99,  99,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([67]), tensor([11])),
#  (tensor([ 4, 11]), tensor([ 67, 124]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([ 67, 124, 124]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([ 67, 124, 124,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([ 67, 124, 124,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([ 67, 124, 124,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([261]), tensor([11])),
#  (tensor([ 4, 11]), tensor([261,  16]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([261,  16,  16]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([261,  16,  16,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([261,  16,  16,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([261,  16,  16,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([210]), tensor([11])),
#  (tensor([ 4, 11]), tensor([210,  66]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([210,  66,  66]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([210,  66,  66,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([210,  66,  66,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([210,  66,  66,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([64]), tensor([9])),
#  (tensor([4, 9]), tensor([64,  5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([ 64,   5, 250]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([ 64,   5, 250,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([ 64,   5, 250,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([ 64,   5, 250,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([79]), tensor([11])),
#  (tensor([ 4, 11]), tensor([79, 75]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([79, 75, 75]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([79, 75, 75,  4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]), tensor([79, 75, 75,  4,  4]), tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([79, 75, 75,  4,  4,  4]),
#   tensor([15])),
#  (tensor([ 4, 11,  9,  5,  6,  8, 15]),
#   tensor([79, 75, 75,  4,  4,  4,  4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([31]), tensor([9])),
#  (tensor([4, 9]), tensor([31,  5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([ 31,   5, 178]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([ 31,   5, 178,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([ 31,   5, 178,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([ 31,   5, 178,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([220]), tensor([9])),
#  (tensor([4, 9]), tensor([220,   5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([220,   5, 145]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([220,   5, 145,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([220,   5, 145,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([220,   5, 145,   4,   4,   4]),
#   tensor([12])),
#  (tensor([ 4,  9, 10,  5,  6,  8, 12]),
#   tensor([220,   5, 145,   4,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([15]), tensor([11])),
#  (tensor([ 4, 11]), tensor([15, 76]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([15, 76, 76]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([15, 76, 76,  4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]), tensor([15, 76, 76,  4,  4]), tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
# ...
#  (tensor([ 4, 11,  9,  5]), tensor([256,  58,  58,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([256,  58,  58,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([256,  58,  58,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([144]), tensor([9])),
#  (tensor([4, 9]), tensor([144,   5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([144,   5,  30]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([144,   5,  30,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([144,   5,  30,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([144,   5,  30,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([191]), tensor([9])),
#  (tensor([4, 9]), tensor([191,   5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([191,   5,  26]), tensor([13])),
#  (tensor([ 4,  9, 10, 13]), tensor([191,   5,  26,  26]), tensor([10])),
#  (tensor([ 4,  9, 10, 13, 10]),
#   tensor([191,   5,  26,  26,  26]),
#   tensor([5])),
#  (tensor([ 4,  9, 10, 13, 10,  5]),
#   tensor([191,   5,  26,  26,  26,   4]),
#   tensor([6])),
#  (tensor([ 4,  9, 10, 13, 10,  5,  6]),
#   tensor([191,   5,  26,  26,  26,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10, 13, 10,  5,  6,  8]),
#   tensor([191,   5,  26,  26,  26,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([54]), tensor([9])),
#  (tensor([4, 9]), tensor([54,  5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([54,  5, 38]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([54,  5, 38,  4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]), tensor([54,  5, 38,  4,  4]), tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([54,  5, 38,  4,  4,  4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([22]), tensor([14])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([30]), tensor([16])),
#  (tensor([ 4, 16]), tensor([30,  6]), tensor([6])),
#  (tensor([ 4, 16,  6]), tensor([30,  6,  6]), tensor([8])),
#  (tensor([ 4, 16,  6,  8]), tensor([30,  6,  6,  6]), tensor([15])),
#  (tensor([ 4, 16,  6,  8, 15]), tensor([30,  6,  6,  6,  6]), tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([260]), tensor([9])),
#  (tensor([4, 9]), tensor([260,   5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([260,   5,  81]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([260,   5,  81,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([260,   5,  81,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([260,   5,  81,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([78]), tensor([11])),
#  (tensor([ 4, 11]), tensor([78, 23]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([78, 23, 23]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([78, 23, 23,  4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]), tensor([78, 23, 23,  4,  4]), tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([78, 23, 23,  4,  4,  4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([116]), tensor([9])),
#  (tensor([4, 9]), tensor([116,  15]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([116,  15,  15]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([116,  15,  15,   4]), tensor([13])),
#  (tensor([ 4,  9, 10,  5, 13]),
#   tensor([116,  15,  15,   4,  15]),
#   tensor([5])),
#  (tensor([ 4,  9, 10,  5, 13,  5]),
#   tensor([116,  15,  15,   4,  15,   4]),
#   tensor([6])),
#  (tensor([ 4,  9, 10,  5, 13,  5,  6]),
#   tensor([116,  15,  15,   4,  15,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5, 13,  5,  6,  8]),
#   tensor([116,  15,  15,   4,  15,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([89]), tensor([9])),
#  (tensor([4, 9]), tensor([89,  5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([89,  5, 23]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([89,  5, 23,  4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]), tensor([89,  5, 23,  4,  4]), tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([89,  5, 23,  4,  4,  4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([23]), tensor([11])),
#  (tensor([ 4, 11]), tensor([23, 16]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([23, 16, 16]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([23, 16, 16,  4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]), tensor([23, 16, 16,  4,  4]), tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([23, 16, 16,  4,  4,  4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([262]), tensor([11])),
#  (tensor([ 4, 11]), tensor([262,  22]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([262,  22,  22]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([262,  22,  22,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([262,  22,  22,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([262,  22,  22,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([247]), tensor([11])),
#  (tensor([ 4, 11]), tensor([247, 132]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([247, 132, 132]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([247, 132, 132,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([247, 132, 132,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([247, 132, 132,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([85]), tensor([9])),
#  (tensor([4, 9]), tensor([85,  5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([85,  5, 97]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([85,  5, 97,  4]), tensor([13])),
#  (tensor([ 4,  9, 10,  5, 13]), tensor([85,  5, 97,  4, 97]), tensor([5])),
#  (tensor([ 4,  9, 10,  5, 13,  5]),
#   tensor([85,  5, 97,  4, 97,  4]),
#   tensor([6])),
#  (tensor([ 4,  9, 10,  5, 13,  5,  6]),
#   tensor([85,  5, 97,  4, 97,  4,  4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5, 13,  5,  6,  8]),
#   tensor([85,  5, 97,  4, 97,  4,  4,  4]),
#   tensor([12])),
#  (tensor([ 4,  9, 10,  5, 13,  5,  6,  8, 12]),
#   tensor([85,  5, 97,  4, 97,  4,  4,  4,  4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([270]), tensor([11])),
#  (tensor([ 4, 11]), tensor([270,  98]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([270,  98,  98]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([270,  98,  98,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([270,  98,  98,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([270,  98,  98,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([63]), tensor([9])),
#  (tensor([4, 9]), tensor([63,  5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([ 63,   5, 205]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([ 63,   5, 205,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([ 63,   5, 205,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([ 63,   5, 205,   4,   4,   4]),
#   tensor([15])),
#  (tensor([ 4,  9, 10,  5,  6,  8, 15]),
#   tensor([ 63,   5, 205,   4,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([223]), tensor([11])),
#  (tensor([ 4, 11]), tensor([223,  21]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([223,  21,  21]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([223,  21,  21,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([223,  21,  21,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([223,  21,  21,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([134]), tensor([9])),
#  (tensor([4, 9]), tensor([134,   5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([134,   5,  37]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([134,   5,  37,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([134,   5,  37,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([134,   5,  37,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([55]), tensor([9])),
#  (tensor([4, 9]), tensor([55,  5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([ 55,   5, 217]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([ 55,   5, 217,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([ 55,   5, 217,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([ 55,   5, 217,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([198]), tensor([11])),
#  (tensor([ 4, 11]), tensor([198,  77]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([198,  77,  77]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([198,  77,  77,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([198,  77,  77,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([198,  77,  77,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([226]), tensor([9])),
#  (tensor([4, 9]), tensor([226,   5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([226,   5, 108]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([226,   5, 108,   4]), tensor([13])),
#  (tensor([ 4,  9, 10,  5, 13]),
#   tensor([226,   5, 108,   4, 108]),
#   tensor([5])),
#  (tensor([ 4,  9, 10,  5, 13,  5]),
#   tensor([226,   5, 108,   4, 108,   4]),
#   tensor([6])),
#  (tensor([ 4,  9, 10,  5, 13,  5,  6]),
#   tensor([226,   5, 108,   4, 108,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5, 13,  5,  6,  8]),
#   tensor([226,   5, 108,   4, 108,   4,   4,   4]),
#   tensor([12])),
#  (tensor([ 4,  9, 10,  5, 13,  5,  6,  8, 12]),
#   tensor([226,   5, 108,   4, 108,   4,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([14]), tensor([9])),
#  (tensor([4, 9]), tensor([14,  5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([14,  5, 96]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([14,  5, 96,  4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]), tensor([14,  5, 96,  4,  4]), tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([14,  5, 96,  4,  4,  4]),
#   tensor([12])),
#  (tensor([ 4,  9, 10,  5,  6,  8, 12]),
#   tensor([14,  5, 96,  4,  4,  4,  4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([134]), tensor([9])),
#  (tensor([4, 9]), tensor([134,   5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([134,   5,  13]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([134,   5,  13,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([134,   5,  13,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([134,   5,  13,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([169]), tensor([9])),
#  (tensor([4, 9]), tensor([169,   5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([169,   5,  32]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([169,   5,  32,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([169,   5,  32,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([169,   5,  32,   4,   4,   4]),
#   tensor([12])),
#  (tensor([ 4,  9, 10,  5,  6,  8, 12]),
#   tensor([169,   5,  32,   4,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([235]), tensor([14])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([183]), tensor([9])),
#  (tensor([4, 9]), tensor([183,   5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([183,   5,  46]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([183,   5,  46,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([183,   5,  46,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([183,   5,  46,   4,   4,   4]),
#   tensor([12])),
#  (tensor([ 4,  9, 10,  5,  6,  8, 12]),
#   tensor([183,   5,  46,   4,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([257]), tensor([11])),
#  (tensor([ 4, 11]), tensor([257,  45]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([257,  45,  45]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([257,  45,  45,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([257,  45,  45,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([257,  45,  45,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([264]), tensor([11])),
#  (tensor([ 4, 11]), tensor([264,  18]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([264,  18,  18]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([264,  18,  18,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([264,  18,  18,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([264,  18,  18,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([200]), tensor([11])),
#  (tensor([ 4, 11]), tensor([200, 118]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([200, 118, 118]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([200, 118, 118,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([200, 118, 118,   4,   4]),
#   tensor([8])),
#  (tensor([ 4, 11,  9,  5,  6,  8]),
#   tensor([200, 118, 118,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([254]), tensor([9])),
#  (tensor([4, 9]), tensor([254,   5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([254,   5, 265]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([254,   5, 265,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([254,   5, 265,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([254,   5, 265,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([251]), tensor([9])),
#  (tensor([4, 9]), tensor([251,   5]), tensor([10])),
#  (tensor([ 4,  9, 10]), tensor([251,   5, 194]), tensor([5])),
#  (tensor([ 4,  9, 10,  5]), tensor([251,   5, 194,   4]), tensor([6])),
#  (tensor([ 4,  9, 10,  5,  6]),
#   tensor([251,   5, 194,   4,   4]),
#   tensor([8])),
#  (tensor([ 4,  9, 10,  5,  6,  8]),
#   tensor([251,   5, 194,   4,   4,   4]),
#   tensor([12])),
#  (tensor([ 4,  9, 10,  5,  6,  8, 12]),
#   tensor([251,   5, 194,   4,   4,   4,   4]),
#   tensor([7])),
#  (tensor([], dtype=torch.int64), tensor([], dtype=torch.int64), tensor([4])),
#  (tensor([4]), tensor([141]), tensor([11])),
#  (tensor([ 4, 11]), tensor([141, 129]), tensor([9])),
#  (tensor([ 4, 11,  9]), tensor([141, 129, 129]), tensor([5])),
#  (tensor([ 4, 11,  9,  5]), tensor([141, 129, 129,   4]), tensor([6])),
#  (tensor([ 4, 11,  9,  5,  6]),
#   tensor([141, 129, 129,   4,   4]),
#   tensor([8])),
#  ...]

# %%
counter = Counter()
counter.update([each_ for each in data_add_prev['prev_acts'] for each_ in each])
counter
# Out:
# Counter({'Request_created': 1152,
#          'Service_closure_Request_with_network_responsibility': 801,
#          'Authorization_Requested': 387,
#          'Service_closure_Request_with_BO_responsibility': 638,
#          'Pending_Request_for_Reservation_Closure': 399,
#          'Pending_Liquidation_Request': 215,
#          'Evaluating_Request_(NO_registered_letter)': 405,
#          'Pending_Request_for_Network_Information': 28,
#          'Back-Office_Adjustment_Requested': 16,
#          'Network_Adjustment_Requested': 87,
#          'Pending_Request_for_acquittance_of_heirs': 18,
#          'Evaluating_Request_(WITH_registered_letter)': 40})

# %%
import torch.nn.functional as F

# %%
a = F.softmax(torch.tensor([[float('-inf'),float('-inf')],[9,9]]), dim=-1)
a[a.isnan()]=0
a
# Out:
# tensor([[0.0000, 0.0000],
#         [0.5000, 0.5000]])

# %%
counter = Counter()
# counter.update([each for each in data_add_prev['prev_acts']])

# %%
counter
# Out:
# Counter({'Request_created': 1152,
#          'Service_closure_Request_with_network_responsibility': 801,
#          'Authorization_Requested': 387,
#          'Service_closure_Request_with_BO_responsibility': 638,
#          'Pending_Request_for_Reservation_Closure': 399,
#          'Pending_Liquidation_Request': 215,
#          'Evaluating_Request_(NO_registered_letter)': 405,
#          'Pending_Request_for_Network_Information': 28,
#          'Back-Office_Adjustment_Requested': 16,
#          'Network_Adjustment_Requested': 87,
#          'Pending_Request_for_acquittance_of_heirs': 18,
#          'Evaluating_Request_(WITH_registered_letter)': 40})
